# %% [markdown]
# # Task 3. Extrapolation of the trailing gaps
#
# Task 3 starts from the cleaned Spiff price data and focuses on the shared trailing missing block that was reserved from Task 2.

# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

repo_root = Path.cwd().parent
sys.path.append(str(repo_root))

from config.plot_config import plot_config
from Subtasks.series_analysis import PriceAnalysis

output = plot_config() / "task3"
output.mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Load the cleaned data

# %%
analysis = PriceAnalysis.from_csv("spiff_data-2.csv").clean()

prices = analysis.prices
prices.head()
# Out:
#        gurkor   guitars  slingshots     stocks     sugar     water  \
# day
# 1    6.154653  2.794285    2.136536  10.653684  3.324896  3.896149
# 2    6.189623  2.843068    2.113582  10.674465  3.355736  3.899915
# 3    6.168641  2.839644    2.116336  10.822372  3.336461  3.897404
# 4    6.156401  2.823384    2.096137  10.848804  3.288274  3.901170
# 5    6.124929  2.832798    2.099810  10.860731  3.303694  3.905355
#
#      tranquillity
# day
# 1        7.755880
# 2        7.781310
# 3        7.886205
# 4        7.848061
# 5        7.883026
